# %%
                                                             SNOWSQL PRACTICE

# %%
C:\Users\PC>snowsql -a arfnxhb-gi90638 -u UBAIDSAGHIR4566
Password:
* SnowSQL * v1.4.5
Type SQL statements or !help
UBAIDSAGHIR4566#COMPUTE_WH@(no database).(no schema)>CREATE WAREHOUSE m_wh
                                                     WITH WAREHOUSE_SIZE =
                                                     'XSMALL'
                                                     AUTO_SUSPEND = 60
                                                     AUTO_RESUME = TRUE;
                                                                            +--------------------------------------+
| status                               |
|--------------------------------------|
| Warehouse M_WH successfully created. |
+--------------------------------------+
1 Row(s) produced. Time Elapsed: 0.932s
UBAIDSAGHIR4566#M_WH@(no database).(no schema)>USE WAREHOUSE m_wh;
                                                                            +----------------------------------+
| status                           |
|----------------------------------|
| Statement executed successfully. |
+----------------------------------+
1 Row(s) produced. Time Elapsed: 0.244s
UBAIDSAGHIR4566#M_WH@(no database).(no schema)>CREATE DATABASE my_db;
                                                                            +--------------------------------------+
| status                               |
|--------------------------------------|
| Database MY_DB successfully created. |
+--------------------------------------+
1 Row(s) produced. Time Elapsed: 0.304s
UBAIDSAGHIR4566#M_WH@MY_DB.PUBLIC>USE DATABASE my_db;
                                                                            +----------------------------------+
| status                           |
|----------------------------------|
| Statement executed successfully. |
+----------------------------------+
1 Row(s) produced. Time Elapsed: 0.379s
UBAIDSAGHIR4566#M_WH@MY_DB.PUBLIC>CREATE SCHEMA my_schema;
                                                                            +----------------------------------------+
| status                                 |
|----------------------------------------|
| Schema MY_SCHEMA successfully created. |
+----------------------------------------+
1 Row(s) produced. Time Elapsed: 0.263s
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>USE SCHEMA my_schema;
                                                                            +----------------------------------+
| status                           |
|----------------------------------|
| Statement executed successfully. |
+----------------------------------+
1 Row(s) produced. Time Elapsed: 0.240s
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>CREATE STAGE my_stage;
                                                                            +-------------------------------------------+
| status                                    |
|-------------------------------------------|
| Stage area MY_STAGE successfully created. |
+-------------------------------------------+
1 Row(s) produced. Time Elapsed: 0.289s
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>CREATE TABLE customers (
                                     id INT,
                                     name STRING,
                                     city STRING
                                     );
                                                                            +---------------------------------------+
| status                                |
|---------------------------------------|
| Table CUSTOMERS successfully created. |
+---------------------------------------+
1 Row(s) produced. Time Elapsed: 1.041s
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>PUT file://C:\Users\PC\Downloads\data/
                                     customers.csv @my_stage;
                                                                            +---------------+------------------+-------------+-------------+--------------------+--------------------+----------+---------+
| source        | target           | source_size | target_size | source_compression | target_compression | status   | message |
|---------------+------------------+-------------+-------------+--------------------+--------------------+----------+---------|
| customers.csv | customers.csv.gz |          93 |         128 | NONE               | GZIP               | UPLOADED |         |
+---------------+------------------+-------------+-------------+--------------------+--------------------+----------+---------+
1 Row(s) produced. Time Elapsed: 2.642s
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>LIST @my_stage;
                                                                            +---------------------------+------+----------------------------------+-------------------------------+
| name                      | size | md5                              | last_modified                 |
|---------------------------+------+----------------------------------+-------------------------------|
| my_stage/customers.csv.gz |  128 | 366cbda4c2d557ccfa5f4eb09073ad15 | Tue, 31 Mar 2026 10:44:49 GMT |
+---------------------------+------+----------------------------------+-------------------------------+
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>CREATE FILE FORMAT my_csv_format
                                     TYPE = CSV
                                     SKIP_HEADER = 1
                                     FIELD_DELIMITER = ',';
                                                                            +-------------------------------------------------+
| status                                          |
|-------------------------------------------------|
| File format MY_CSV_FORMAT successfully created. |
+-------------------------------------------------+
1 Row(s) produced. Time Elapsed: 0.945s
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>COPY INTO customers
                                     FROM @my_stage/customers.csv
                                     FILE_FORMAT = my_csv_format;
                                                                            +---------------------------+--------+-------------+-------------+-------------+-------------+-------------+------------------+-----------------------+-------------------------+
| file                      | status | rows_parsed | rows_loaded | error_limit | errors_seen | first_error | first_error_line | first_error_character | first_error_column_name |
|---------------------------+--------+-------------+-------------+-------------+-------------+-------------+------------------+-----------------------+-------------------------|
| my_stage/customers.csv.gz | LOADED |           4 |           4 |           1 |           0 | NULL        |             NULL |                  NULL | NULL                    |
+---------------------------+--------+-------------+-------------+-------------+-------------+-------------+------------------+-----------------------+-------------------------+
1 Row(s) produced. Time Elapsed: 1.120s
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>SELECT * FROM customers;
                                                                            +----+--------+-----------+
| ID | NAME   | CITY      |
|----+--------+-----------|
|  1 | Ali    | Karachi   |
|  2 | Ahmed  | Lahore    |
|  3 | Sara   | Islamabad |
|  4 | Ayesha | Lahore    |
+----+--------+-----------+
4 Row(s) produced. Time Elapsed: 0.712s
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>PUT file://C:\Users\PC\Downloads\data\
                                     New folder\*.csv @my_stage;
                                                                            001003 (42000): SQL compilation error:
parse error line 1 at position 49 near '42'.
syntax error line 1 at position 50 unexpected '.'.
syntax error line 1 at position 55 unexpected '@my_stage'.
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>PUT file://C:\Users\PC\Downloads\data\
                                     New folder\*.csv @my_stage;
                                                                            001003 (42000): SQL compilation error:
parse error line 1 at position 49 near '42'.
syntax error line 1 at position 50 unexpected '.'.
syntax error line 1 at position 55 unexpected '@my_stage'.
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>PUT file://C:\Users\PC\Downloads\data\
                                     Newfolder\*.csv@my_stage;
                                                                            001003 (42000): SQL compilation error:
syntax error line 1 at position 62 unexpected ';'.
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>PUT "file://C:/Users/PC/Downloads/data
                                     /New folder/*.csv" @my_stage;
                                                                            001003 (42000): SQL compilation error:
syntax error line 1 at position 4 unexpected '"file://C:/Users/PC/Downloads/data/New folder/*.csv"'.
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>PUT file//C:\Users\PC\Downloads\data\New_folder\*
                                     .csv\ @my_stage;
001003 (42000): SQL compilation error:
syntax error line 1 at position 4 unexpected 'file'.
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>PUT file://C:\Users\PC\Downloads\data\New_folder\
                                     *.csv\ @my_stage;
253006 (n/a): File doesn't exist: ['C:\\Users\\PC\\Downloads\\data\\New_folder\\*.csv\\']
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>PUT file://C:\Users\PC\Downloads\data\New_folder\
                                     *.csv @my_stage;
253006 (n/a): File doesn't exist: ['C:\\Users\\PC\\Downloads\\data\\New_folder\\*.csv']
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>PUT file://C:\Users\PC\Downloads\data\New folder\
                                     *.csv @my_stage;
001003 (42000): SQL compilation error:
parse error line 1 at position 49 near '42'.
syntax error line 1 at position 50 unexpected '.'.
syntax error line 1 at position 55 unexpected '@my_stage'.
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>PUT "file://C:/Users/PC/Downloads/data
                                     /New folder/*.csv" @my_stage;
                                                                            001003 (42000): SQL compilation error:
syntax error line 1 at position 4 unexpected '"file://C:/Users/PC/Downloads/data/New folder/*.csv"'.
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>SELECT * FROM customers;
                                                                            +----+--------+-----------+
| ID | NAME   | CITY      |
|----+--------+-----------|
|  1 | Ali    | Karachi   |
|  2 | Ahmed  | Lahore    |
|  3 | Sara   | Islamabad |
|  4 | Ayesha | Lahore    |
+----+--------+-----------+
4 Row(s) produced. Time Elapsed: 1.045s
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>PUT file://C:\Users\PC\Downloads\data\
                                     New folder\*.csv @my_stage;
                                                                            001003 (42000): SQL compilation error:
parse error line 1 at position 49 near '42'.
syntax error line 1 at position 50 unexpected '.'.
syntax error line 1 at position 55 unexpected '@my_stage'.
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>PUT file://C:\Users\PC\Downloads\data\
                                     New folder\*.csv @my_stage;
                                                                            001003 (42000): SQL compilation error:
parse error line 1 at position 49 near '42'.
syntax error line 1 at position 50 unexpected '.'.
syntax error line 1 at position 55 unexpected '@my_stage'.
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>CREATE STAGE testing;
                                                                            +------------------------------------------+
| status                                   |
|------------------------------------------|
| Stage area TESTING successfully created. |
+------------------------------------------+
1 Row(s) produced. Time Elapsed: 0.264s
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>PUT file://C:\Users\PC\Downloads\data\
                                     New folder\*.csv @testing;
                                                                            001003 (42000): SQL compilation error:
parse error line 1 at position 49 near '42'.
syntax error line 1 at position 50 unexpected '.'.
syntax error line 1 at position 55 unexpected '@testing'.
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>PUT file://C:\Users\PC\Downloads\data\
                                     New_folder/*.csv @testing;
                                                                            +-----------------+--------------------+-------------+-------------+--------------------+--------------------+----------+---------+
| source          | target             | source_size | target_size | source_compression | target_compression | status   | message |
|-----------------+--------------------+-------------+-------------+--------------------+--------------------+----------+---------|
| order_items.csv | order_items.csv.gz |          99 |         112 | NONE               | GZIP               | UPLOADED |         |
| orders.csv      | orders.csv.gz      |         117 |         112 | NONE               | GZIP               | UPLOADED |         |
| products.csv    | products.csv.gz    |         113 |         128 | NONE               | GZIP               | UPLOADED |         |
+-----------------+--------------------+-------------+-------------+--------------------+--------------------+----------+---------+
3 Row(s) produced. Time Elapsed: 2.440s
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>GET @testing "file:D:\New_folder";
                                                                            001003 (42000): SQL compilation error:
syntax error line 1 at position 13 unexpected '"file:D:\New_folder"'.
syntax error line 1 at position 33 unexpected ';'.
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>GET @testing file:D:\New_folder;
                                                                            001003 (42000): SQL compilation error:
syntax error line 1 at position 13 unexpected 'file'.
syntax error line 1 at position 17 unexpected ':'.
syntax error line 1 at position 19 unexpected ':'.
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>GET @testing file://D:\New_folder;
                                                                            +--------------------+------+------------+---------+
| file               | size | status     | message |
|--------------------+------+------------+---------|
| order_items.csv.gz |  104 | DOWNLOADED |         |
| orders.csv.gz      |  103 | DOWNLOADED |         |
| products.csv.gz    |  121 | DOWNLOADED |         |
+--------------------+------+------------+---------+
3 Row(s) produced. Time Elapsed: 2.630s
UBAIDSAGHIR4566#M_WH@MY_DB.MY_SCHEMA>
